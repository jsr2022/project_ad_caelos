# %%
from adcaelos.components.base_component import Base_Component
from adcaelos.components.time_varying_component import Time_Varying_Component
from adcaelos.components.truth_component import Truth_Component
from adcaelos.components.logic_component import Logic_Component

testBase_Component         = Base_Component()
testTime_Varying_Component = Time_Varying_Component()
aa = dict()
bb = dict()
testTruth_Component        = Truth_Component(aa, bb)
testLogic_Component        = Logic_Component(testTruth_Component)

print(testBase_Component)
print("")
print(testTime_Varying_Component)
print("")
print(testTruth_Component)
print("")
print(testLogic_Component)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 10
#       8 aa = dict()
#       9 bb = dict()
# ---> 10 testTruth_Component        = Truth_Component(aa, bb)
#      11 testLogic_Component        = Logic_Component(testTruth_Component)
#      13 print(testBase_Component)
#
# File ~/repos/project_ad_caelos/adcaelos/components/truth_component.py:11, in Truth_Component.__init__(self, statePos2Names, stateNames2Pos, integratorType, nextTime, frequency, name, UUID)
#      10 def __init__(self, statePos2Names: dict, stateNames2Pos: dict, integratorType: Integrator_Enums = Integrator_Enums.RK4, nextTime: float = -1, frequency: int = 100, name: str = "Truth_Component", UUID: int = None) -> None:
# ---> 11     super().__init__(nextTime, frequency, Component_Enums.TRUTH_COMPONENT, name, UUID)
#      12     self.__statePos2Names = statePos2Names #dictionary of keys (state indices in state vector) to values (state names)
#      13     self.__stateNames2Pos = stateNames2Pos #dictionary of keys (state names) to values (state indices in state vector)
#
# TypeError: Time_Varying_Component.__init__() takes from 1 to 5 positional arguments but 6 were given
