# %%
from adcaelos.components.base_component import Base_Component
from adcaelos.components.dt_component import Dt_Component

testBase_Component = Base_Component()
testDt_Component   = Dt_Component()

print(testBase_Component)
print(testDt_Component)
# Out:
# This is a component class of type Component_Enums.BASE_COMPONENT.
# It has the name Base_Component.
# Its UUID is 629403454.
# This is a component class of type Component_Enums.DT_COMPONENT.
# It has the name Dt_Component.
# Its UUID is 2970465017.
# ADDSTUFFHERE
